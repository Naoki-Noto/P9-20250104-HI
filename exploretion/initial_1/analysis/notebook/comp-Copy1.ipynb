# %%
import pandas as pd
from collections import Counter

# %%
# データの全体リスト
"""
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_7.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl', 'Reaction_CS', 
                  'Reaction_CN', 'Reaction_2+2', 'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_OCH2F', 'Reaction_SCF3',
                 'Reaction_Masuda', 'Reaction_Sumida']
"""
target = 'Reaction_CO_Cl'

comparison_dict = {
    "first_select_avarage": 0,
    "second_select_average": 1,
    "third_select_average": 2,
    "last_select_average": -1,
}

# 結果を格納する辞書
result_tables = {}

print("~*~" * 15)
print(f"{target}")

# 入力辞書
data_names_dict = {
        'BayesianOptimization_GPyOpt_EI_RBF': f'BayesianOptimization_{target}_GPyOpt_EI_RBF_result',
        #'TrAdaBoostR2_Q_XGB_ne3_sourceAll': f'TrAdaBoostR2_Q_XGB_ne3_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_LGBM_ne3_sourceAll': f'TrAdaBoostR2_Q_LGBM_ne3_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourceAll': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourceAll': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_XGB_ne10_sourceAll': f'TrAdaBoostR2_Q_XGB_ne10_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_LGBM_ne10_sourceAll': f'TrAdaBoostR2_Q_LGBM_ne10_{target}_sourceAll_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcetop1': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcetop1_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourcetop1': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcetop1_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcetop3': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcetop3_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourcetop3': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcetop3_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcetop5': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcetop5_result',
        'TrAdaBoostR2_Q_LGBM_ne5_sourcetop5': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcetop5_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcebottom1': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcebottom1_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourcebottom1': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcebottom1_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcebottom3': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcebottom3_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourcebottom3': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcebottom3_result',
        #'TrAdaBoostR2_Q_XGB_ne5_sourcebottom5': f'TrAdaBoostR2_Q_XGB_ne5_{target}_sourcebottom5_result',
        #'TrAdaBoostR2_Q_LGBM_ne5_sourcebottom5': f'TrAdaBoostR2_Q_LGBM_ne5_{target}_sourcebottom5_result',
        'XGBRegression': f'XGBRegression_{target}_result', 
        'LinearRegression_standard': f'LinearRegression_{target}_standard_result', 
        #'HGBRegressor': f'HGBRegressor_{target}_result',
        'RFRegression': f'RFRegression_{target}_result', 
}
inverse_dict = {v: k for k, v in data_names_dict.items()}

# データを格納する辞書
data_frames = {}

# ファイルの読み込みと変換
for name in data_names_dict.values():
    file_path = f"../results/{name}_select_averages.csv"  # ファイルパス
    df = pd.read_csv(file_path)  # データフレームを読み込む
    df.columns = [name]  # 列名をデータフレーム名に変更
    data_frames[name] = df  # 辞書に保存
    
comparison_table = pd.concat(data_frames.values(), axis=1)

print(comparison_table)
        
print("~*~" * 15)
# Out:
# ~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~~*~
# Reaction_CO_Cl
#    BayesianOptimization_Reaction_CO_Cl_GPyOpt_EI_RBF_result  \
# 0                                               8.18
# 1                                              13.86
# 2                                              19.87
# 3                                              27.38
# 4                                              39.83
#
#    TrAdaBoostR2_Q_LGBM_ne5_Reaction_CO_Cl_sourcetop5_result  \
# 0                                               1.94
# 1                                               3.42
# 2                                               6.59
# 3                                               8.16
# 4                                              10.14
#
#    XGBRegression_Reaction_CO_Cl_result  \
# 0                                 2.87
# 1                                 6.39
# 2                                11.57
# 3                                16.97
# 4                                26.28
#
# ...
