# %%
import pandas as pd
import ast
import numpy as np

# %%
print('== BO_UCB ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_UCB/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == BO_UCB ==
# Reaction_CO_1.5h: avg=29.17, std=7.51
# Reaction_CO_biphenyl: avg=24.60, std=3.69
# Reaction_CO_ortho: avg=12.32, std=3.06
# Reaction_CO_Cl: avg=34.27, std=6.64
# Reaction_CS: avg=30.58, std=11.59
# Reaction_CN: avg=7.08, std=3.58
# Reaction_2+2: avg=30.43, std=4.36
# Reaction_CF3: avg=27.25, std=7.58
# Reaction_CH2CF3: avg=29.52, std=7.30
# Reaction_CH2F: avg=22.77, std=4.91
# Reaction_Cy: avg=29.83, std=11.20
# Reaction_SCF3: avg=37.90, std=7.31

# %%
print('== RF ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results/RFsearch/RFsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == RF ==
# Reaction_CO_1.5h: avg=28.83, std=8.99
# Reaction_CO_biphenyl: avg=12.58, std=6.62
# Reaction_CO_ortho: avg=15.72, std=6.89
# Reaction_CO_Cl: avg=23.40, std=12.33
# Reaction_CS: avg=15.75, std=13.05
# Reaction_CN: avg=7.03, std=5.31
# Reaction_2+2: avg=21.28, std=8.65
# Reaction_CF3: avg=22.83, std=11.76
# Reaction_CH2CF3: avg=18.97, std=8.54
# Reaction_CH2F: avg=14.43, std=6.40
# Reaction_Cy: avg=27.37, std=11.82
# Reaction_SCF3: avg=18.22, std=8.72

# %%
print('== TrAB_top3_e0_ne5 ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results_others/TrABsearch_top3_e0_ne5/TrABsearch_{data}_top3_e0_ne5_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == TrAB_top3_e0_ne5 ==
# Reaction_CO_1.5h: avg=12.97, std=4.05
# Reaction_CO_biphenyl: avg=4.80, std=2.93
# Reaction_CO_ortho: avg=13.18, std=3.27
# Reaction_CO_Cl: avg=4.13, std=3.25
# Reaction_CS: avg=3.93, std=2.32
# Reaction_CN: avg=9.32, std=4.21
# Reaction_2+2: avg=20.18, std=5.55
# Reaction_CF3: avg=35.40, std=9.21
# Reaction_CH2CF3: avg=15.68, std=5.96
# Reaction_CH2F: avg=12.63, std=4.06
# Reaction_Cy: avg=10.28, std=5.02
# Reaction_SCF3: avg=13.47, std=7.70

# %%
print('== TrAB_top3_e10%_ne5 ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results_others/TrABsearch_top3_e10%_ne5/TrABsearch_{data}_top3_e0.1_ne5_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == TrAB_top3_e10%_ne5 ==
# Reaction_CO_1.5h: avg=12.68, std=6.45
# Reaction_CO_biphenyl: avg=7.33, std=3.20
# Reaction_CO_ortho: avg=15.37, std=3.46
# Reaction_CO_Cl: avg=6.90, std=5.82
# Reaction_CS: avg=8.55, std=6.23
# Reaction_CN: avg=3.70, std=2.14
# Reaction_2+2: avg=20.55, std=6.85
# Reaction_CF3: avg=35.52, std=12.34
# Reaction_CH2CF3: avg=19.48, std=5.88
# Reaction_CH2F: avg=15.13, std=6.29
# Reaction_Cy: avg=14.73, std=9.64
# Reaction_SCF3: avg=19.40, std=6.76

# %%
print('== TrAB_all_e0_ne5 ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results_others/TrABsearch_all_e0_ne5/TrABsearch_{data}_top14_e0_ne5_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == TrAB_all_e0_ne5 ==
# Reaction_CO_1.5h: avg=25.27, std=6.83
# Reaction_CO_biphenyl: avg=3.90, std=1.39
# Reaction_CO_ortho: avg=14.33, std=2.25
# Reaction_CO_Cl: avg=2.87, std=0.92
# Reaction_CS: avg=3.27, std=0.96
# Reaction_CN: avg=9.95, std=3.95
# Reaction_2+2: avg=12.38, std=2.00
# Reaction_CF3: avg=47.28, std=6.73
# Reaction_CH2CF3: avg=34.50, std=6.43
# Reaction_CH2F: avg=15.22, std=3.34
# Reaction_Cy: avg=6.67, std=0.89
# Reaction_SCF3: avg=26.98, std=5.92

# %%
print('== BO_UCB_sc ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_UCB_sc/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == BO_UCB_sc ==
# Reaction_CO_1.5h: avg=29.17, std=7.51
# Reaction_CO_biphenyl: avg=24.60, std=3.69
# Reaction_CO_ortho: avg=12.32, std=3.06
# Reaction_CO_Cl: avg=34.27, std=6.64
# Reaction_CS: avg=30.58, std=11.59
# Reaction_CN: avg=7.08, std=3.58
# Reaction_2+2: avg=30.43, std=4.36
# Reaction_CF3: avg=27.25, std=7.58
# Reaction_CH2CF3: avg=29.52, std=7.30
# Reaction_CH2F: avg=22.77, std=4.91
# Reaction_Cy: avg=29.83, std=11.20
# Reaction_SCF3: avg=37.90, std=7.31
