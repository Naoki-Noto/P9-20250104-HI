# %%
import pandas as pd
import ast
import numpy as np

# %%
print('== BO_UCB ==')
All_data_names = ['Reaction_cross',]
for data in All_data_names:
    df = pd.read_csv(f"../results_added_publicdata/BOsearch_UCB/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == BO_UCB ==
# Reaction_cross: avg=15.35, std=4.11

# %%
print('== RF ==')
All_data_names = ['Reaction_cross',]
for data in All_data_names:
    df = pd.read_csv(f"../results_added_publicdata/RFsearch/RFsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == RF ==
# Reaction_cross: avg=9.96, std=5.32

# %%
print('== TrAB_all_e0_ne5 ==')
All_data_names = ['Reaction_cross',]
for data in All_data_names:
    df = pd.read_csv(f"../results_added_publicdata/TrABsearch_all_e0_ne5/TrABsearch_{data}_top15_e0_ne5_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == TrAB_all_e0_ne5 ==
# Reaction_cross: avg=16.24, std=5.98
