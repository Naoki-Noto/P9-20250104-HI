# %%
from ModelbaseSearch_TL import TrABsearch

# %%
TrABsearch(target='Reaction_cross', n_OPS=55, epsilon=0, ne=5, selection_order='top', n_source=15,
           data_dir="../../data/data_added_publicdata", result_dir="../results_added_publicdata/TrABsearch_all_e0_ne5")

# %%
TrABsearch(target='Reaction_cross', n_OPS=55, epsilon=0.1, ne=5, selection_order='top', n_source=15,
           data_dir="../../data/data_added_publicdata", result_dir="../results_added_publicdata/TrABsearch_all_e10%_ne5")
# Out:
# Running TrABsearch for Reaction_cross...
