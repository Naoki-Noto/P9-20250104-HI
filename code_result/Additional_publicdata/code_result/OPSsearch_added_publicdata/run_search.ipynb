# %%
from ModelbaseSearch import RFsearch

# %%
RFsearch(target='Reaction_cross', n_OPS=55, epsilon=0,
         data_dir="../../data/data_added_publicdata", result_dir="../results_added_publicdata/RFsearch")
# Out:
# Running RFsearch for Reaction_cross...
