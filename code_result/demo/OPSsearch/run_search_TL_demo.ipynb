# %%
from ModelbaseSearch_TL_demo import TrABsearch

# %%
TrABsearch(target='Reaction_P', n_OPS=60, epsilon=0.1, ne=5, selection_order='top',
           data_dir="../../../data/data_60", n_source=5, result_dir="../results/TrABsearch_top5_e10%_ne5")
# Out:
# Running TrABsearch for Reaction_P...
# Step 1: OPS1 is selected.
# The top 30 OPSs with the highest predicted yields are then displayed.
#     Predicted_Yield     ID
# 10            86.15  OPS12
# 5             85.87   OPS7
# 9             85.85  OPS11
# 8             85.70  OPS10
# 7             72.89   OPS9
# 0             67.47   OPS2
# 31            66.79  OPS33
# 13            65.27  OPS15
# 15            65.07  OPS17
# 48            65.01  OPS50
# 2             61.67   OPS4
# 6             60.48   OPS8
# 1             59.84   OPS3
# 12            57.18  OPS14
# 11            54.52  OPS13
# 4             53.26   OPS6
# 36            51.55  OPS38
# 20            51.05  OPS22
# 17            50.40  OPS19
# 21            49.91  OPS23
# 37            46.12  OPS39
# 18            46.05  OPS20
# 28            42.82  OPS30
# 23            42.06  OPS25
# 29            41.79  OPS31
# 30            41.69  OPS32
# 25            41.23  OPS27
# 16            41.18  OPS18
# 19            39.84  OPS21
# 34            39.26  OPS36
# One round of the search is completed...
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*
# Random value used for epsilon-greedy: 0.64
# Step 2: OPS12 is selected (Pred Yield: 86%, Actual Yield: 95%).
# After obtaining the experimental yield, a TrAB model is constructed to predict the expected yields of the remaining OPSs.
# First, correlation coefficients are calculated.
# ====================================================================================
# Since there are only two data points, the correlation coefficient is either 1 or -1.
# Therefore, for Step 3, all reactions are used as the source domain.
# ====================================================================================
# The top 30 OPSs with the highest predicted yields are then displayed.
#     Predicted_Yield     ID
# 5             89.82   OPS7
# 9             89.68  OPS11
# 8             88.83  OPS10
# 7             77.78   OPS9
# 12            70.15  OPS15
# 30            68.04  OPS33
# 6             67.73   OPS8
# 0             67.57   OPS2
# 14            66.08  OPS17
# 47            65.70  OPS50
# 2             62.61   OPS4
# 1             60.67   OPS3
# 11            58.62  OPS14
# 10            55.81  OPS13
# 19            55.00  OPS22
# 16            54.02  OPS19
# 4             53.67   OPS6
# 20            53.54  OPS23
# 35            49.37  OPS38
# 36            48.23  OPS39
# 29            47.74  OPS32
# 17            47.55  OPS20
# 22            45.97  OPS25
# 15            44.26  OPS18
# 24            44.20  OPS27
# 28            43.94  OPS31
# 27            43.86  OPS30
# 33            43.50  OPS36
# 23            42.22  OPS26
# 18            41.29  OPS21
# One round of the search is completed...
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*
# Random value used for epsilon-greedy: 0.03
# =======================================
# random_value < 0.1 => **random search**
# =======================================
# Step 3: OPS23 is selected (Pred Yield: 54%, Actual Yield: 0%).
# After obtaining the experimental yield, a TrAB model is constructed to predict the expected yields of the remaining OPSs.
# For selecting the source domain, correlation coefficients are calculated.
# ==============================================================================================
# Selected reactions as the source domain:
# ['Reaction_CO_biphenyl', 'Reaction_CS', 'Reaction_2+2', 'Reaction_CH2F', 'Reaction_CO_1.5h']
# ==============================================================================================
# The top 30 OPSs with the highest predicted yields are then displayed.
#     Predicted_Yield     ID
# 9             85.90  OPS11
# 5             84.89   OPS7
# 7             71.52   OPS9
# 2             69.61   OPS4
# 0             68.07   OPS2
# 8             67.09  OPS10
# 1             62.70   OPS3
# 29            59.79  OPS33
# 6             58.47   OPS8
# 11            58.14  OPS14
# 4             58.02   OPS6
# 10            57.90  OPS13
# 46            53.26  OPS50
# 34            52.12  OPS38
# 12            50.90  OPS15
# 35            40.07  OPS39
# 16            37.30  OPS19
# 14            35.51  OPS17
# 21            34.52  OPS25
# 27            32.61  OPS31
# 32            29.89  OPS36
# 24            26.51  OPS28
# 22            26.22  OPS26
# 18            25.37  OPS21
# 3             24.93   OPS5
# 28            24.23  OPS32
# 17            23.85  OPS20
# 19            23.44  OPS22
# 25            19.43  OPS29
# 37            18.60  OPS41
# One round of the search is completed...
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*
# Random value used for epsilon-greedy: 0.28
# Step 4: OPS11 is selected (Pred Yield: 86%, Actual Yield: 79%).
# After obtaining the experimental yield, a TrAB model is constructed to predict the expected yields of the remaining OPSs.
# For selecting the source domain, correlation coefficients are calculated.
# ==============================================================================================
# Selected reactions as the source domain:
# ['Reaction_CO_biphenyl', 'Reaction_CS', 'Reaction_2+2', 'Reaction_CO_1.5h', 'Reaction_CO_Cl']
# ==============================================================================================
# The top 30 OPSs with the highest predicted yields are then displayed.
#     Predicted_Yield     ID
# 5             82.35   OPS7
# 8             74.41  OPS10
# 7             69.88   OPS9
# 0             66.17   OPS2
# 2             65.83   OPS4
# 1             60.17   OPS3
# 6             58.60   OPS8
# 9             57.69  OPS13
# 45            56.21  OPS50
# 10            52.58  OPS14
# 28            52.46  OPS33
# 4             49.76   OPS6
# 11            47.29  OPS15
# 13            46.23  OPS17
# 15            39.50  OPS19
# 33            38.04  OPS38
# 26            33.76  OPS31
# 20            33.57  OPS25
# 18            29.20  OPS22
# 21            28.98  OPS26
# 27            28.86  OPS32
# 23            28.45  OPS28
# 34            26.16  OPS39
# 16            25.99  OPS20
# 17            24.39  OPS21
# 12            24.39  OPS16
# 3             23.44   OPS5
# 24            21.04  OPS29
# 14            20.66  OPS18
# 31            19.86  OPS36
# One round of the search is completed...
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*
# Random value used for epsilon-greedy: 0.22
# Step 5: OPS7 is selected (Pred Yield: 82%, Actual Yield: 0%).
# After obtaining the experimental yield, a TrAB model is constructed to predict the expected yields of the remaining OPSs.
# For selecting the source domain, correlation coefficients are calculated.
# ==============================================================================================
# Selected reactions as the source domain:
# ['Reaction_CS', 'Reaction_CO_biphenyl', 'Reaction_2+2', 'Reaction_CO_1.5h', 'Reaction_CO_Cl']
# ==============================================================================================
# The top 30 OPSs with the highest predicted yields are then displayed.
#     Predicted_Yield     ID
# 2             63.94   OPS4
# 0             62.86   OPS2
# 8             58.61  OPS13
# 1             58.31   OPS3
# 6             55.54   OPS9
# 27            53.93  OPS33
# 9             53.37  OPS14
# 7             53.15  OPS10
# 44            53.06  OPS50
# 4             49.29   OPS6
# 5             47.07   OPS8
# 12            30.13  OPS17
# 10            26.47  OPS15
# 11            25.88  OPS16
# 25            25.37  OPS31
# 20            24.62  OPS26
# 32            24.02  OPS38
# 22            22.45  OPS28
# 26            22.15  OPS32
# 3             19.69   OPS5
# 33            19.46  OPS39
# 23            16.67  OPS29
# 17            16.16  OPS22
# 14            16.05  OPS19
# 19            15.03  OPS25
# 48            14.70  OPS54
# 21            11.66  OPS27
# 15            11.41  OPS20
# 24            11.39  OPS30
# 13            11.17  OPS18
# One round of the search is completed...
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*
# Random value used for epsilon-greedy: 0.74
# Step 6: OPS4 is selected (Pred Yield: 64%, Actual Yield: 5%).
# After obtaining the experimental yield, a TrAB model is constructed to predict the expected yields of the remaining OPSs.
# For selecting the source domain, correlation coefficients are calculated.
# ==============================================================================================
# Selected reactions as the source domain:
# ['Reaction_CS', 'Reaction_2+2', 'Reaction_CO_biphenyl', 'Reaction_CO_1.5h', 'Reaction_CO_Cl']
# ==============================================================================================
#   ·
#   ·
# Repeat until all OPSs are selected.
#   ·
#   ·
#   ·
#   ·
# Repeat until each OPS has been used once as the initially selected OPS.

# %%
import pandas as pd
import ast

df = pd.read_csv("../results/TrABsearch_top5_e10%_ne5/TrABsearch_Reaction_P_top5_e0.1_ne5_result.csv")
all_selected_str = df.loc[0, 'selected_indices_per_step']
all_selected = ast.literal_eval(all_selected_str)
ops_names = [f"OPS{i+1}" for i in all_selected]
print(", ".join(ops_names) + " were selected.")
# Out:
# OPS1, OPS12, OPS23, OPS11, OPS7, OPS4 were selected.
