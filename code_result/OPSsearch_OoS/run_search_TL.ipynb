# %%
from ModelbaseSearch_TL import TrABsearch

# %%
TrABsearch(target='Reaction_CO_biphenyl', n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=5,
           data_dir="../../data/data_61/data_61_CO_biphenyl", result_dir="../results_OoS/TrABsearch_top5_e0_ne5")
# Out:
# Running TrABsearch for Reaction_CO_biphenyl...

# %%
TrABsearch(target='Reaction_CO_biphenyl', n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=3,
           data_dir="../../data/data_61/data_61_CO_biphenyl", result_dir="../results_OoS/TrABsearch_top3_e0_ne5")
# Out:
# Running TrABsearch for Reaction_CO_biphenyl...

# %%
TrABsearch(target='Reaction_CO_biphenyl', n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=14,
           data_dir="../../data/data_61/data_61_CO_biphenyl", result_dir="../results_OoS/TrABsearch_all_e0_ne5")
# Out:
# Running TrABsearch for Reaction_CO_biphenyl...
