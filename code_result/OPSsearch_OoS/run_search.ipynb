# %%
from ModelbaseSearch import RFsearch

# %%
RFsearch(target='Reaction_CO_biphenyl', n_OPS=60, epsilon=0, data_dir="../../data/data_61/data_woTL_61_CO_biphenyl", result_dir="../results_OoS/RFsearch")
# Out:
# Running RFsearch for Reaction_CO_biphenyl...
